# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Data Augmentation for Training
train_datagen = ImageDataGenerator(
    rotation_range=15,        # Slight rotation (Bell's Palsy is sensitive to asymmetry)
    width_shift_range=0.1,   # Small horizontal shifts
    height_shift_range=0.1,  # Small vertical shifts
    shear_range=0.1,         # Mild shear distortions
    zoom_range=0.1,          # Slight zoom
    horizontal_flip=True,    # Critical for facial symmetry tasks
    fill_mode='nearest',     # Fill missing pixels
    rescale=1./255           # Normalize pixel values
)

# %%
# Validation/Test Data (No Augmentation)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Dataset Paths
train_dir = "/content/drive/MyDrive/Datasets2/Train"
val_dir = "/content/drive/MyDrive/Datasets2/Validation"
test_dir = "/content/drive/MyDrive/Datasets2/Test"

# %%
train_set = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_set = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_set = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # For correct confusion matrix
)
# Out:
# Found 960 images belonging to 4 classes.
# Found 120 images belonging to 4 classes.
# Found 120 images belonging to 4 classes.

# %%
# Class Weighting (if imbalanced)
class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(train_set.classes),
    y=train_set.classes
)
class_weights = dict(enumerate(class_weights))

# %%
# Model Architecture
def build_model(learning_rate=1e-4):
    base_model = ResNet50(
        input_shape=(224, 224, 3),
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False  # Freeze pretrained layers initially

    # Custom Head for Better Feature Extraction
    x = base_model.output
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)  # Added conv layer
    x = BatchNormalization()(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)  # High dropout to prevent overfitting
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    predictions = Dense(len(train_set.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # The following two lines were incorrectly indented in the original code.
    # They need to be indented to be part of the build_model function.
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

# %%
# Train with 3 Learning Rates (Test Which Works Best)
learning_rates = [1e-4, 3e-5, 1e-5]  # Empirically strong choices

for lr in learning_rates:
    print(f"\nTraining with LR = {lr}")
    model = build_model(learning_rate=lr)
    history = model.fit(
        train_set,
        validation_data=val_set,
        epochs=30,
        class_weight=class_weights,
        callbacks=[early_stopping, reduce_lr]
    )
# Out:
# Training with LR = 0.0001
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 501s 16s/step - accuracy: 0.4904 - loss: 1.2445 - val_accuracy: 0.2500 - val_loss: 1.3813 - learning_rate: 1.0000e-04
# Epoch 2/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 777ms/step - accuracy: 0.7125 - loss: 0.8263 - val_accuracy: 0.4833 - val_loss: 1.2147 - learning_rate: 1.0000e-04
# Epoch 3/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 678ms/step - accuracy: 0.8198 - loss: 0.5996 - val_accuracy: 0.3667 - val_loss: 1.2414 - learning_rate: 1.0000e-04
# Epoch 4/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 617ms/step - accuracy: 0.8587 - loss: 0.4747 - val_accuracy: 0.5167 - val_loss: 1.1854 - learning_rate: 1.0000e-04
# Epoch 5/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 632ms/step - accuracy: 0.8997 - loss: 0.3627 - val_accuracy: 0.7167 - val_loss: 1.1440 - learning_rate: 1.0000e-04
# Epoch 6/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 619ms/step - accuracy: 0.9098 - loss: 0.3106 - val_accuracy: 0.3250 - val_loss: 1.2231 - learning_rate: 1.0000e-04
# Epoch 7/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 640ms/step - accuracy: 0.9256 - loss: 0.2767 - val_accuracy: 0.6250 - val_loss: 1.0707 - learning_rate: 1.0000e-04
# Epoch 8/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 630ms/step - accuracy: 0.9496 - loss: 0.2235 - val_accuracy: 0.5583 - val_loss: 0.9934 - learning_rate: 1.0000e-04
# Epoch 9/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 621ms/step - accuracy: 0.9490 - loss: 0.1927 - val_accuracy: 0.5083 - val_loss: 1.1143 - learning_rate: 1.0000e-04
# Epoch 10/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 677ms/step - accuracy: 0.9483 - loss: 0.1841 - val_accuracy: 0.5917 - val_loss: 1.0829 - learning_rate: 1.0000e-04
# Epoch 11/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 625ms/step - accuracy: 0.9704 - loss: 0.1416 - val_accuracy: 0.7250 - val_loss: 0.9193 - learning_rate: 1.0000e-04
# Epoch 12/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 689ms/step - accuracy: 0.9556 - loss: 0.1607 - val_accuracy: 0.5417 - val_loss: 1.0170 - learning_rate: 1.0000e-04
# Epoch 13/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 638ms/step - accuracy: 0.9665 - loss: 0.1335 - val_accuracy: 0.5917 - val_loss: 1.1854 - learning_rate: 1.0000e-04
# Epoch 14/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 639ms/step - accuracy: 0.9729 - loss: 0.1203
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 674ms/step - accuracy: 0.9729 - loss: 0.1203 - val_accuracy: 0.6000 - val_loss: 1.1776 - learning_rate: 1.0000e-04
# Epoch 15/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 631ms/step - accuracy: 0.9788 - loss: 0.1022 - val_accuracy: 0.5750 - val_loss: 1.0853 - learning_rate: 5.0000e-05
# Epoch 16/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 700ms/step - accuracy: 0.9697 - loss: 0.0882 - val_accuracy: 0.5750 - val_loss: 0.8704 - learning_rate: 5.0000e-05
# Epoch 17/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 634ms/step - accuracy: 0.9780 - loss: 0.0819 - val_accuracy: 0.5917 - val_loss: 1.1004 - learning_rate: 5.0000e-05
# Epoch 18/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 676ms/step - accuracy: 0.9810 - loss: 0.0741 - val_accuracy: 0.6083 - val_loss: 1.0417 - learning_rate: 5.0000e-05
# Epoch 19/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.9837 - loss: 0.0698
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 635ms/step - accuracy: 0.9836 - loss: 0.0700 - val_accuracy: 0.5500 - val_loss: 1.3621 - learning_rate: 5.0000e-05
# Epoch 20/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 678ms/step - accuracy: 0.9713 - loss: 0.0959 - val_accuracy: 0.6167 - val_loss: 1.1580 - learning_rate: 2.5000e-05
# Epoch 21/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 629ms/step - accuracy: 0.9811 - loss: 0.0741 - val_accuracy: 0.5917 - val_loss: 1.7307 - learning_rate: 2.5000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 16.
#
# Training with LR = 3e-05
# Epoch 1/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 879ms/step - accuracy: 0.3811 - loss: 1.3438 - val_accuracy: 0.1583 - val_loss: 1.3690 - learning_rate: 3.0000e-05
# Epoch 2/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 712ms/step - accuracy: 0.6503 - loss: 1.1768 - val_accuracy: 0.1750 - val_loss: 1.3269 - learning_rate: 3.0000e-05
# Epoch 3/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 639ms/step - accuracy: 0.6756 - loss: 1.0264 - val_accuracy: 0.4083 - val_loss: 1.2762 - learning_rate: 3.0000e-05
# Epoch 4/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 671ms/step - accuracy: 0.7429 - loss: 0.8550 - val_accuracy: 0.4917 - val_loss: 1.2346 - learning_rate: 3.0000e-05
# Epoch 5/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 641ms/step - accuracy: 0.8104 - loss: 0.6989 - val_accuracy: 0.4000 - val_loss: 1.2164 - learning_rate: 3.0000e-05
# Epoch 6/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 698ms/step - accuracy: 0.8195 - loss: 0.6321 - val_accuracy: 0.3917 - val_loss: 1.2167 - learning_rate: 3.0000e-05
# Epoch 7/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 637ms/step - accuracy: 0.8606 - loss: 0.5303 - val_accuracy: 0.4500 - val_loss: 1.2029 - learning_rate: 3.0000e-05
# Epoch 8/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 654ms/step - accuracy: 0.8818 - loss: 0.4865 - val_accuracy: 0.5417 - val_loss: 1.1013 - learning_rate: 3.0000e-05
# Epoch 9/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 625ms/step - accuracy: 0.8940 - loss: 0.4193 - val_accuracy: 0.4833 - val_loss: 1.1422 - learning_rate: 3.0000e-05
# Epoch 10/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 634ms/step - accuracy: 0.9214 - loss: 0.3693 - val_accuracy: 0.5583 - val_loss: 1.0752 - learning_rate: 3.0000e-05
# Epoch 11/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 646ms/step - accuracy: 0.9247 - loss: 0.3564 - val_accuracy: 0.6083 - val_loss: 0.9853 - learning_rate: 3.0000e-05
# Epoch 12/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 617ms/step - accuracy: 0.9212 - loss: 0.3169 - val_accuracy: 0.5000 - val_loss: 1.2162 - learning_rate: 3.0000e-05
# Epoch 13/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 669ms/step - accuracy: 0.9354 - loss: 0.2867 - val_accuracy: 0.5917 - val_loss: 0.9906 - learning_rate: 3.0000e-05
# Epoch 14/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.9360 - loss: 0.2693
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 616ms/step - accuracy: 0.9360 - loss: 0.2690 - val_accuracy: 0.5000 - val_loss: 1.2347 - learning_rate: 3.0000e-05
# Epoch 15/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 664ms/step - accuracy: 0.9378 - loss: 0.2492 - val_accuracy: 0.5917 - val_loss: 1.0488 - learning_rate: 1.5000e-05
# Epoch 16/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 633ms/step - accuracy: 0.9589 - loss: 0.2240 - val_accuracy: 0.5917 - val_loss: 1.1595 - learning_rate: 1.5000e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# Training with LR = 1e-05
# Epoch 1/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 835ms/step - accuracy: 0.3626 - loss: 1.3797 - val_accuracy: 0.4417 - val_loss: 1.4421 - learning_rate: 1.0000e-05
# Epoch 2/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 31s 675ms/step - accuracy: 0.4817 - loss: 1.3117 - val_accuracy: 0.2583 - val_loss: 1.3954 - learning_rate: 1.0000e-05
# Epoch 3/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 637ms/step - accuracy: 0.5777 - loss: 1.2252 - val_accuracy: 0.2750 - val_loss: 1.3603 - learning_rate: 1.0000e-05
# Epoch 4/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 687ms/step - accuracy: 0.6056 - loss: 1.1445 - val_accuracy: 0.4583 - val_loss: 1.3366 - learning_rate: 1.0000e-05
# Epoch 5/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 636ms/step - accuracy: 0.6125 - loss: 1.0964 - val_accuracy: 0.4417 - val_loss: 1.3182 - learning_rate: 1.0000e-05
# Epoch 6/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 674ms/step - accuracy: 0.6432 - loss: 1.0120 - val_accuracy: 0.4083 - val_loss: 1.2866 - learning_rate: 1.0000e-05
# Epoch 7/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 637ms/step - accuracy: 0.6587 - loss: 0.9623 - val_accuracy: 0.3750 - val_loss: 1.2577 - learning_rate: 1.0000e-05
# Epoch 8/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 673ms/step - accuracy: 0.6630 - loss: 0.9101 - val_accuracy: 0.3833 - val_loss: 1.2310 - learning_rate: 1.0000e-05
# Epoch 9/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 632ms/step - accuracy: 0.6793 - loss: 0.8532 - val_accuracy: 0.3833 - val_loss: 1.2059 - learning_rate: 1.0000e-05
# Epoch 10/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 704ms/step - accuracy: 0.6959 - loss: 0.8325 - val_accuracy: 0.3750 - val_loss: 1.1784 - learning_rate: 1.0000e-05
# Epoch 11/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 639ms/step - accuracy: 0.7202 - loss: 0.8034 - val_accuracy: 0.3833 - val_loss: 1.2046 - learning_rate: 1.0000e-05
# Epoch 12/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 694ms/step - accuracy: 0.7187 - loss: 0.7592 - val_accuracy: 0.3833 - val_loss: 1.1616 - learning_rate: 1.0000e-05
# Epoch 13/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 647ms/step - accuracy: 0.7208 - loss: 0.7504 - val_accuracy: 0.3917 - val_loss: 1.1558 - learning_rate: 1.0000e-05
# Epoch 14/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 701ms/step - accuracy: 0.7443 - loss: 0.7284 - val_accuracy: 0.4083 - val_loss: 1.1076 - learning_rate: 1.0000e-05
# Epoch 15/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 656ms/step - accuracy: 0.7847 - loss: 0.6621 - val_accuracy: 0.4250 - val_loss: 1.1064 - learning_rate: 1.0000e-05
# Epoch 16/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 687ms/step - accuracy: 0.8115 - loss: 0.6129 - val_accuracy: 0.4000 - val_loss: 1.1312 - learning_rate: 1.0000e-05
# Epoch 17/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 648ms/step - accuracy: 0.8241 - loss: 0.6044 - val_accuracy: 0.4333 - val_loss: 1.1463 - learning_rate: 1.0000e-05
# Epoch 18/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 705ms/step - accuracy: 0.8632 - loss: 0.5534 - val_accuracy: 0.5750 - val_loss: 1.0391 - learning_rate: 1.0000e-05
# Epoch 19/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 635ms/step - accuracy: 0.8257 - loss: 0.5815 - val_accuracy: 0.4833 - val_loss: 1.1144 - learning_rate: 1.0000e-05
# Epoch 20/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 690ms/step - accuracy: 0.8385 - loss: 0.5309 - val_accuracy: 0.5417 - val_loss: 1.0454 - learning_rate: 1.0000e-05
# Epoch 21/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.8519 - loss: 0.5242
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 658ms/step - accuracy: 0.8523 - loss: 0.5237 - val_accuracy: 0.5417 - val_loss: 1.0657 - learning_rate: 1.0000e-05
# Epoch 22/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 688ms/step - accuracy: 0.8670 - loss: 0.4901 - val_accuracy: 0.5583 - val_loss: 1.0664 - learning_rate: 5.0000e-06
# Epoch 23/30
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 642ms/step - accuracy: 0.8780 - loss: 0.4968 - val_accuracy: 0.5417 - val_loss: 1.1213 - learning_rate: 5.0000e-06
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
    model.save(f"bellspalsy_model_lr_{lr}.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_loss, test_acc = model.evaluate(test_set)
print(f"Test Accuracy (LR={lr}): {test_acc:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 11s/step - accuracy: 0.9712 - loss: 0.4386
# Test Accuracy (LR=1e-05): 0.9750

# %%
from tensorflow.keras.models import load_model # Import the load_model function

best_model = load_model(f"bellspalsy_model_lr_{lr}.h5")  # Replace with best LR

for layer in best_model.layers[-20:]:
    layer.trainable = True

best_model.compile(
    optimizer=Adam(learning_rate=1e-5),  # Lower LR for fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_finetune = best_model.fit(
    train_set,
    validation_data=val_set,
    epochs=10,
    callbacks=[early_stopping]
)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 1/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 43s 866ms/step - accuracy: 0.7754 - loss: 0.8232 - val_accuracy: 0.4667 - val_loss: 1.2297
# Epoch 2/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 657ms/step - accuracy: 0.8228 - loss: 0.6052 - val_accuracy: 0.5750 - val_loss: 1.3920
# Epoch 3/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 678ms/step - accuracy: 0.8894 - loss: 0.4634 - val_accuracy: 0.4667 - val_loss: 1.4341
# Epoch 4/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 706ms/step - accuracy: 0.9177 - loss: 0.3655 - val_accuracy: 0.5833 - val_loss: 1.6028
# Epoch 5/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 20s 658ms/step - accuracy: 0.9440 - loss: 0.3002 - val_accuracy: 0.4083 - val_loss: 1.7105
# Epoch 6/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 701ms/step - accuracy: 0.9298 - loss: 0.2928 - val_accuracy: 0.3750 - val_loss: 1.7499
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
y_pred = best_model.predict(test_set)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_set.classes

print("Classification Report:")
print(classification_report(y_true, y_pred_classes))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86        30
#            1       0.00      0.00      0.00        30
#            2       0.91      1.00      0.95        30
#            3       0.56      1.00      0.71        30
#
#     accuracy                           0.72       120
#    macro avg       0.57      0.72      0.63       120
# weighted avg       0.57      0.72      0.63       120
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# 1. Binarize the true labels (for multi-class ROC)
y_true = test_set.classes
y_true_bin = label_binarize(y_true, classes=np.unique(y_true))
n_classes = y_true_bin.shape[1]

# 2. Get predicted probabilities
y_pred_prob = model.predict(test_set)

# 3. Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 4. Plot ROC curves
plt.figure(figsize=(8, 6))
colors = cycle(['blue', 'red', 'green', 'orange'])  # Adjust colors to match # of classes

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='Class {0} (AUC = {1:0.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step

# %%
import matplotlib.pyplot as plt

# Function to plot training history
def plot_history(history):
    # Extract training history
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)  # Get number of epochs

    # Plot Accuracy
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training & Validation Accuracy')
    plt.legend()

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training & Validation Loss')
    plt.legend()

    plt.show()

# Call the function with model history
plot_history(history)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')  # Weighted for imbalanced classes
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.7250
# Precision: 0.5707
# Recall: 0.7250
# F1 Score: 0.6310
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
plt.savefig("confusion_matrix.png", dpi=300)
plt.show()


# 1. Get true labels and predictions
y_true = test_set.classes
y_pred = model.predict(test_set)
y_pred_classes = np.argmax(y_pred, axis=1)

# 2. Generate confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# 3. Plot with annotations and improved visuals
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_set.class_indices.keys(),
            yticklabels=test_set.class_indices.keys())
plt.title('Confusion Matrix (Test Set)', fontsize=14)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# 4. Print classification metrics
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes,
                          target_names=test_set.class_indices.keys()))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# Classification Report:
#                  precision    recall  f1-score   support
#
#            Mild       0.94      1.00      0.97        30
#        Moderate       1.00      0.93      0.97        30
# Moderate Severe       1.00      0.97      0.98        30
#          Severe       0.97      1.00      0.98        30
#
#        accuracy                           0.97       120
#       macro avg       0.98      0.97      0.97       120
#    weighted avg       0.98      0.97      0.97       120

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import load_model
best_model=load_model(f"bellspalsy_model_lr_{lr}.h5")

def predict_and_display(image_path, model, class_labels):

    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    prediction = model.predict(img_array)
    predicted_class_index = np.argmax(prediction)

    predicted_class_label = class_labels[predicted_class_index]

    plt.imshow(img)
    plt.axis('off')
    plt.title(f"The Prediction is: {predicted_class_label}")
    plt.show()

# Load your trained model
best_model.load_weights(f"bellspalsy_model_lr_{lr}.h5")

# Define your class labels (e.g., ['car', 'truck', ...])
class_labels = [ 'mild eyes', 'moderate eyes', 'moderate severe eyes', 'severe eyes']

# Replace 'path_to_test_image' with the path to the image you want to test
image_1 = r"/content/drive/MyDrive/Datasets2/Test/Mild/14_Mi_eye1.bmp"
image_2 = r"/content/drive/MyDrive/Datasets2/Test/Moderate/1_M_eye12.bmp"

predict_and_display(image_1, model, class_labels)
predict_and_display(image_2, model, class_labels)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
